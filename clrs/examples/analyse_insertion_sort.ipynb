# %% [markdown]
# # Results

# %%
! pip install wandb matplotlib pandas numpy
# Out:
# Requirement already satisfied: wandb in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (0.19.8)
# Requirement already satisfied: matplotlib in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: pandas in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (2.2.4)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (5.29.4)
# Requirement already satisfied: psutil>=5.0.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (7.0.0)
# Requirement already satisfied: pydantic<3,>=2.6 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (2.10.6)
# Requirement already satisfied: pyyaml in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (2.24.1)
# Requirement already satisfied: setproctitle in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (1.3.5)
# Requirement already satisfied: setuptools in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (65.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from wandb) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.4.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2025.1.31)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/cb2318/L65_Project/L65Project/.venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
import wandb
import pandas as pd
import numpy as np
from datetime import datetime
import yaml

# %%
wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: biermann-carla (biermann-carla-university-of-cambridge) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
def get_runs(entity, project):
    api = wandb.Api(timeout=30)
    wandb_filters = {
        "config.algorithms": ["insertion_sort"],
        "state": "finished",
    }
    runs = api.runs(f"{entity}/{project}", filters=wandb_filters) 
    print(f"Found {len(runs)} runs.")
    history = []
    filtered_runs = []
    for run in runs:
        created_at = datetime.strptime(run.created_at, "%Y-%m-%dT%H:%M:%SZ")
        runtime = run.summary.get("_runtime", 0)
        if (
            created_at >= datetime(2025, 3, 24) # started on March 24
            and 10 * 60 <= runtime <= 11 * 3600 # between 10 minutes and 11 hours
        ):
            history_data = run.history()  # Fetch full history
            history_data = history_data[history_data["_step"] <= 80000]  # Keep only <= 80k steps

            history.append({"config": dict(run.config), **history_data.iloc[-1].to_dict()})  # Append only last valid step
            filtered_runs.append(run)

    print(f"{len(filtered_runs)} filtered runs")
    df = pd.json_normalize(history)
    return filtered_runs, df

# %%
# Takes about 7 minutes
runs, df = get_runs("biermann-carla-university-of-cambridge", "L65-project")
# Out:
# Found 49 runs.
# 18 filtered runs

# %%
df
# Out:
#     insertion_sort_test_aggregated_msg_avg_norm  insertion_sort_val_j_entropy  \
# 0                                           NaN                           NaN
# 1                                           NaN                           NaN
# 2                                           NaN                           NaN
# 3                                           NaN                           NaN
# 4                                           NaN                           NaN
# 5                                           NaN                           NaN
# 6                                           NaN                           NaN
# 7                                           NaN                           NaN
# 8                                           NaN                           NaN
# 9                                           NaN                           NaN
# 10                                          NaN                           NaN
# 11                                          NaN                           NaN
# 12                                          NaN                           NaN
# 13                                          NaN                           NaN
# 14                                          NaN                           NaN
# 15                                          NaN                           NaN
# 16                                          NaN                           NaN
# 17                                          NaN                           NaN
#
#     insertion_sort_aggregated_msg_mean  \
# 0                            13.793355
# 1                            -3.173209
# 2                             0.106677
# 3                             7.041901
# 4                            -0.506094
# 5                             5.251039
# 6                             8.265682
# 7                            -0.577068
# 8                            11.852423
# 9                             2.633747
# 10                           10.599380
# 11                            3.139179
# 12                           -0.676739
# 13                           -2.991495
# 14                          -14.786640
# 15                           -3.731923
# 16                          -14.254004
# 17                           -0.469641
#
#     insertion_sort_test_post_subtraction_premlpmsg_mean  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#     insertion_sort_postmlpmsg_avg_norm  \
# 0                           652.441772
# 1                           766.517761
# 2                          1790.064697
# 3                          3133.040039
# 4                           657.984436
# 5                           430.787750
# 6                          2113.494873
# 7                          2686.196045
# 8                           393.684204
# 9                          1937.247437
# 10                          625.570007
# 11                         1431.567871
# 12                         1745.172852
# 13                         4769.558594
# 14                         1539.828003
# 15                         2457.302002
# 16                         1995.719727
# 17                         4060.014404
#
#     insertion_sort_val_aggregated_msg_combined_avg_norm  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#     insertion_sort_test_j_entropy  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                            NaN
#
#     insertion_sort_test_aggregated_msg_combined_avg_norm  model_weights_norm  \
# 0                                                 NaN                    NaN
# 1                                                 NaN                    NaN
# 2                                                 NaN                    NaN
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8                                                 NaN                    NaN
# 9                                                 NaN                    NaN
# 10                                                NaN                    NaN
# 11                                                NaN                    NaN
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
# 16                                                NaN                    NaN
# 17                                                NaN                    NaN
#
#     insertion_sort_test_no_subtraction_premlpmsg_avg_norm  ...  \
# 0                                                 NaN      ...
# 1                                                 NaN      ...
# 2                                                 NaN      ...
# 3                                                 NaN      ...
# 4                                                 NaN      ...
# 5                                                 NaN      ...
# 6                                                 NaN      ...
# 7                                                 NaN      ...
# 8                                                 NaN      ...
# 9                                                 NaN      ...
# 10                                                NaN      ...
# 11                                                NaN      ...
# 12                                                NaN      ...
# 13                                                NaN      ...
# 14                                                NaN      ...
# 15                                                NaN      ...
# 16                                                NaN      ...
# 17                                                NaN      ...
#
#     config.mpnn_processor_aggregator  \
# 0                                max
# 1                                max
# 2                                max
# 3                                max
# 4                                max
# 5                                max
# 6                                max
# 7                                max
# 8                                max
# 9                                max
# 10                               max
# 11                               max
# 12                               max
# 13                               max
# 14                               max
# 15                               max
# 16                               max
# 17                               max
#
#     insertion_sort_val_msg_kappa_subtrahend_mean  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
#
#     insertion_sort_val_msg_kappa_subtrahend_avg_norm  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
#
#     insertion_sort_msg_kappa_subtrahend_avg_std  \
# 0                                           NaN
# 1                                           NaN
# 2                                     21.883280
# 3                                           NaN
# 4                                     22.446213
# 5                                           NaN
# 6                                     34.384384
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                    22.620682
# 11                                    24.771929
# 12                                    23.006739
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
#
#     insertion_sort_test_msg_kappa_subtrahend_mean  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
#
#     insertion_sort_test_msg_kappa_subtrahend_avg_norm  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
#
#     insertion_sort_msg_kappa_subtrahend_mean  \
# 0                                        NaN
# 1                                        NaN
# 2                                  10.213956
# 3                                        NaN
# 4                                   3.218350
# 5                                        NaN
# 6                                   0.873057
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                  2.428026
# 11                                 10.699766
# 12                                 10.463516
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
#
#     insertion_sort_val_msg_kappa_subtrahend_avg_std  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
#
#     insertion_sort_msg_kappa_subtrahend_avg_norm  \
# 0                                            NaN
# 1                                            NaN
# 2                                     276.785736
# 3                                            NaN
# 4                                     261.925903
# 5                                            NaN
# 6                                     395.265900
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                    259.694458
# 11                                    307.979706
# 12                                    289.095062
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
#
#     insertion_sort_test_msg_kappa_subtrahend_avg_std
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
#
# [18 rows x 138 columns]

# %%
full_df = df

# %%
full_df["config.algorithms"] = full_df["config.algorithms"].apply(lambda x: x[0])

# %%
full_df.pivot_table(
    index=[
        "config.processor_type",
        "config.hint_teacher_forcing",
        "config.mpnn_processor_aggregator",
    ],
    values=[
        "test_score_current_model_insertion_sort",
        "insertion_sort_test_score",
    ],
    aggfunc=np.mean,
)
# Out:
# /tmp/ipykernel_1855176/1238595994.py:1: FutureWarning: The provided callable <function mean at 0x7774cc961f30> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   full_df.pivot_table(
# Empty DataFrame
# Columns: []
# Index: []

# %%
algorithm = full_df["config.algorithms"]
print(algorithm)
print(
    full_df[full_df["config.algorithms"] == algorithm][
        ["config.processor_type", f"test_score_current_model_{algorithm}"]
    ].to_markdown()
)
print()
# Out:
# 0     insertion_sort
# 1     insertion_sort
# 2     insertion_sort
# 3     insertion_sort
# 4     insertion_sort
# 5     insertion_sort
# 6     insertion_sort
# 7     insertion_sort
# 8     insertion_sort
# 9     insertion_sort
# 10    insertion_sort
# 11    insertion_sort
# 12    insertion_sort
# 13    insertion_sort
# 14    insertion_sort
# 15    insertion_sort
# 16    insertion_sort
# 17    insertion_sort
# Name: config.algorithms, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       1 algorithm = full_df["config.algorithms"]
#       2 print(algorithm)
#       3 print(
# ----> 4     full_df[full_df["config.algorithms"] == algorithm][
#       5         ["config.processor_type", f"test_score_current_model_{algorithm}"]
#       6     ].to_markdown()
#       7 )
#       8 print()
#
# File ~/L65_Project/L65Project/.venv/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/L65_Project/L65Project/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/L65_Project/L65Project/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['test_score_current_model_0     insertion_sort\\n1     insertion_sort\\n2     insertion_sort\\n3     insertion_sort\\n4     insertion_sort\\n5     insertion_sort\\n6     insertion_sort\\n7     insertion_sort\\n8     insertion_sort\\n9     insertion_sort\\n10    insertion_sort\\n11    insertion_sort\\n12    insertion_sort\\n13    insertion_sort\\n14    insertion_sort\\n15    insertion_sort\\n16    insertion_sort\\n17    insertion_sort\\nName: config.algorithms, dtype: object'] not in index"

# %% [markdown]
# # Results Analysis

# %%
# Extract configurations from matching runs
filtered_configs = {run.name: run.config for run in runs}

# Save to a config file
with open("filtered_configs_insertion_sort.yaml", "w") as f:
    yaml.dump(filtered_configs, f)

print(f"Saved {len(filtered_configs)} filtered configs.")
# Out:
# Saved 15 filtered configs.

# %%
# Extract scores for all runs
all_scores = {}

score_field = "charts/eval_avg_episodic_reward_new"
for run in runs:
    cfg = run.config
    summary = run.summary

    print(run.name, "\n", cfg, "\n", summary)
    break
# Out:
# 2025-03-24 14:08:21-['insertion_sort']-differential_mpnn_maxmax-ablate_subtract
#  {'seed': 42, 'use_ln': True, 'nb_heads': 1, 'use_lstm': False, 'hint_mode': 'encoded_decoded', 'algorithms': ['insertion_sort'], 'batch_size': 32, 'eval_every': 500, 'random_pos': True, 'test_every': 500, 'hidden_size': 128, 'train_steps': 100000, 'chunk_length': 16, 'dataset_path': '/tmp/CLRS30', 'dropout_prob': 0, 'encoder_init': 'xavier_on_scalars', 'learning_rate': 0.001, 'length_needle': -8, 'train_lengths': ['4', '7', '11', '13', '16'], 'nb_triplet_fts': 8, 'processor_type': 'differential_mpnn_maxmax-ablate_subtract', 'checkpoint_path': '/tmp/CLRS30', 'chunked_training': False, 'freeze_processor': False, 'hint_repred_mode': 'soft', 'grad_clip_max_norm': 1, 'enforce_permutations': True, 'hint_teacher_forcing': 0, 'nb_msg_passing_steps': 1, 'enforce_pred_as_input': True, 'mpnn_processor_aggregator': 'max'}
#  {'_runtime': 23814.54557141, '_step': 100000, '_timestamp': 1742849117.4234157, '_wandb': {'runtime': 23814}, 'best_avg_val_score': 1, 'cur_avg_val_score': 0.994140625, 'insertion_sort_aggregated_msg_avg_norm': 621.2586059570312, 'insertion_sort_aggregated_msg_avg_std': 50.16175842285156, 'insertion_sort_aggregated_msg_combined_avg_norm': 603.4011840820312, 'insertion_sort_aggregated_msg_combined_avg_std': 40.25019073486328, 'insertion_sort_aggregated_msg_combined_mean': 34.926910400390625, 'insertion_sort_aggregated_msg_mean': 21.908039093017575, 'insertion_sort_aggregated_msg_postdiff_avg_norm': 621.2586059570312, 'insertion_sort_aggregated_msg_postdiff_avg_std': 50.16175842285156, 'insertion_sort_aggregated_msg_postdiff_mean': 21.908039093017575, 'insertion_sort_examples_seen': 3200000, 'insertion_sort_i_entropy': 0.007376126013696194, 'insertion_sort_j_entropy': 0.0019606181886047125, 'insertion_sort_loss': 0.3615498840808869, 'insertion_sort_loss_truth_i': 0.02483891323208809, 'insertion_sort_loss_truth_j': 0.0002504518779460341, 'insertion_sort_loss_truth_pred_h': 0.008454924449324608, 'insertion_sort_new_embedding_avg_norm': 12.92212963104248, 'insertion_sort_new_embedding_avg_std': 1.1241214275360107, 'insertion_sort_new_embedding_mean': 0.20026786625385284, 'insertion_sort_no_subtraction_premlpmsg_avg_norm': 322.8190002441406, 'insertion_sort_no_subtraction_premlpmsg_avg_std': 23.271434783935547, 'insertion_sort_no_subtraction_premlpmsg_mean': -15.76457977294922, 'insertion_sort_output_loss': 0.3280055820941925, 'insertion_sort_post_subtraction_premlpmsg_avg_norm': 322.8190002441406, 'insertion_sort_post_subtraction_premlpmsg_avg_std': 23.271434783935547, 'insertion_sort_post_subtraction_premlpmsg_mean': -15.76457977294922, 'insertion_sort_postmlpmsg_avg_norm': 968.2217407226562, 'insertion_sort_postmlpmsg_avg_std': 68.69696807861328, 'insertion_sort_postmlpmsg_mean': -50.27308654785156, 'insertion_sort_postmlpmsg_potentially_postsubtracted_avg_norm': 968.2217407226562, 'insertion_sort_postmlpmsg_potentially_postsubtracted_avg_std': 68.69696807861328, 'insertion_sort_postmlpmsg_potentially_postsubtracted_mean': -50.27308654785156, 'insertion_sort_pred_h_entropy': -0.660714328289032, 'insertion_sort_test_aggregated_msg_avg_norm': 699.66162109375, 'insertion_sort_test_aggregated_msg_avg_std': 54.33882522583008, 'insertion_sort_test_aggregated_msg_combined_avg_norm': 683.2078857421875, 'insertion_sort_test_aggregated_msg_combined_avg_std': 44.4024658203125, 'insertion_sort_test_aggregated_msg_combined_mean': 40.88166046142578, 'insertion_sort_test_aggregated_msg_mean': 29.09143447875977, 'insertion_sort_test_aggregated_msg_postdiff_avg_norm': 699.66162109375, 'insertion_sort_test_aggregated_msg_postdiff_avg_std': 54.33882522583008, 'insertion_sort_test_aggregated_msg_postdiff_mean': 29.09143447875977, 'insertion_sort_test_i_entropy': 1.050350308418274, 'insertion_sort_test_j_entropy': 1.118354320526123, 'insertion_sort_test_new_embedding_avg_norm': 12.179600715637209, 'insertion_sort_test_new_embedding_avg_std': 1.0543195009231567, 'insertion_sort_test_new_embedding_mean': 0.2157764583826065, 'insertion_sort_test_no_subtraction_premlpmsg_avg_norm': 314.9847106933594, 'insertion_sort_test_no_subtraction_premlpmsg_avg_std': 22.96196937561035, 'insertion_sort_test_no_subtraction_premlpmsg_mean': -15.016763687133787, 'insertion_sort_test_post_subtraction_premlpmsg_avg_norm': 314.9847106933594, 'insertion_sort_test_post_subtraction_premlpmsg_avg_std': 22.96196937561035, 'insertion_sort_test_post_subtraction_premlpmsg_mean': -15.016763687133787, 'insertion_sort_test_postmlpmsg_avg_norm': 977.703857421875, 'insertion_sort_test_postmlpmsg_avg_std': 69.09342193603516, 'insertion_sort_test_postmlpmsg_mean': -50.94805145263672, 'insertion_sort_test_postmlpmsg_potentially_postsubtracted_avg_norm': 977.703857421875, 'insertion_sort_test_postmlpmsg_potentially_postsubtracted_avg_std': 69.09342193603516, 'insertion_sort_test_postmlpms ...
